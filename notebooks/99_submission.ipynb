# %%
import subprocess
from pathlib import Path

WORKING_DIR = Path("/kaggle/working")
ADAPTER_OUTPUT_DIR = "/kaggle/input/models/rohitraje0493/nemotron-3-nano/transformers/lora-dpo/9"
SUBMISSION_FILE = WORKING_DIR / "submission.zip"

# !rm -rf {SUBMISSION_FILE}

subprocess.run(f"zip -r {SUBMISSION_FILE} *", cwd=ADAPTER_OUTPUT_DIR, shell=True, check=True)
# Out:
#   adding: README.md (deflated 65%)
#   adding: adapter_config.json (deflated 58%)
#   adding: adapter_model.safetensors (deflated 8%)
#   adding: chat_template.jinja (deflated 78%)
#   adding: optimizer.pt (deflated 11%)
#   adding: rng_state.pth (deflated 26%)
#   adding: scheduler.pt (deflated 62%)
#   adding: special_tokens_map.json (deflated 76%)
#   adding: tokenizer.json (deflated 84%)
#   adding: tokenizer_config.json (deflated 96%)
#   adding: trainer_state.json (deflated 76%)
#   adding: training_args.bin (deflated 53%)
# CompletedProcess(args='zip -r /kaggle/working/submission.zip *', returncode=0)
